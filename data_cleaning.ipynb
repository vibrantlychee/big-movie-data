# %% [markdown]
# # Data Cleaning
#
# ## Setup
# Import the relevant packages.

# %%
import ast
import pandas as pd

# %% [markdown]
# We have a single file `20220310.csv`. Let's first look at what type of data we
# are dealing with.

# %%
# load in csv as dataframes
# lineterminator option is used as there are some line separation issues.
raw_data = pd.read_csv("raw-data/20220310.csv", lineterminator="\n")

# get summary information on the data frame, including columns and data types
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  5000 non-null   bool
#  1   backdrop_path          4874 non-null   object
#  2   belongs_to_collection  1742 non-null   object
#  3   budget                 5000 non-null   int64
#  4   genres                 5000 non-null   object
#  5   homepage               2418 non-null   object
#  6   id                     5000 non-null   int64
#  7   imdb_id                4938 non-null   object
#  8   original_language      5000 non-null   object
#  9   original_title         5000 non-null   object
#  10  overview               4963 non-null   object
#  11  popularity             5000 non-null   float64
#  12  poster_path            4995 non-null   object
#  13  production_companies   5000 non-null   object
#  14  production_countries   5000 non-null   object
#  15  release_date           4980 non-null   object
#  16  revenue                5000 non-null   int64
#  17  runtime                4999 non-null   float64
#  18  spoken_languages       5000 non-null   object
#  19  status                 5000 non-null   object
#  20  tagline                3750 non-null   object
#  21  title                  5000 non-null   object
#  22  video                  5000 non-null   bool
#  23  vote_average           5000 non-null   float64
#  24  vote_count             5000 non-null   int64
#  25  credits                5000 non-null   object
#  26  keywords               5000 non-null   object
# dtypes: bool(2), float64(3), int64(4), object(18)
# memory usage: 986.5+ KB

# %% [markdown]
# Let's also look at the first few rows to see what we are dealing with.

# %%
raw_data.head()
raw_data.iloc[[0]].transpose()
# Out:
#                                                                        0
# adult                                                              False
# backdrop_path                           /iQFcwSGbZXMkeyKrxbPnwnRo5fl.jpg
# belongs_to_collection  {'id': 531241, 'name': 'Spider-Man (Avengers) ...
# budget                                                         200000000
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# homepage                            https://www.spidermannowayhome.movie
# id                                                                634649
# imdb_id                                                       tt10872600
# original_language                                                     en
# original_title                                   Spider-Man: No Way Home
# overview               Peter Parker is unmasked and no longer able to...
# popularity                                                     10552.154
# poster_path                             /1g0dhYtq4irTY1GPXvft6k4YLjm.jpg
# production_companies   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  2021-12-15
# revenue                                                       1876685954
# runtime                                                            148.0
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                                        The Multiverse unleashed.
# title                                            Spider-Man: No Way Home
# video                                                              False
# vote_average                                                         8.3
# vote_count                                                          9509
# credits                {'cast': [{'adult': False, 'gender': 2, 'id': ...
# keywords               {'keywords': [{'id': 242, 'name': 'new york ci...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# First we remove columns that we will obviously not be using, e.g. `backdrop_path`,
# `homepage`, etc.

# %%
useless_columns = ["backdrop_path", "belongs_to_collection", "homepage", 
"poster_path", "video"]

raw_data.drop(useless_columns, axis=1, inplace=True)
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 5000 non-null   bool
#  1   budget                5000 non-null   int64
#  2   genres                5000 non-null   object
#  3   id                    5000 non-null   int64
#  4   imdb_id               4938 non-null   object
#  5   original_language     5000 non-null   object
#  6   original_title        5000 non-null   object
#  7   overview              4963 non-null   object
#  8   popularity            5000 non-null   float64
#  9   production_companies  5000 non-null   object
#  10  production_countries  5000 non-null   object
#  11  release_date          4980 non-null   object
#  12  revenue               5000 non-null   int64
#  13  runtime               4999 non-null   float64
#  14  spoken_languages      5000 non-null   object
#  15  status                5000 non-null   object
#  16  tagline               3750 non-null   object
#  17  title                 5000 non-null   object
#  18  vote_average          5000 non-null   float64
#  19  vote_count            5000 non-null   int64
#  20  credits               5000 non-null   object
#  21  keywords              5000 non-null   object
# dtypes: bool(1), float64(3), int64(4), object(14)
# memory usage: 825.3+ KB

# %% [markdown]
# Next we parse `release_date` as a column of date objects, and convert `status` into a Boolean column (`True` for released, `False` otherwise) named `released`.

# %%
# parse dates
raw_data["release_date"] = pd.to_datetime(raw_data["release_date"])
# convert status column to Boolean, and only keep released films
raw_data["released"] = raw_data["status"] == "Released"
raw_data.drop(columns=["status"])
# Out:
#       adult     budget                                             genres  \
# 0     False  200000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1     False  185000000  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 2     False          0  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 3     False   50000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4     False          0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...     ...        ...                                                ...
# 4995  False          0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 4996  False   80000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4997  False          0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 4998  False   33000000  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 4999  False          0  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#           id     imdb_id original_language                    original_title  \
# 0     634649  tt10872600                en           Spider-Man: No Way Home
# 1     414906   tt1877830                en                        The Batman
# 2     833425   tt7550014                en                           No Exit
# 3     568124   tt2953050                en                           Encanto
# 4     928381  tt14465894                fr                        Sans répit
# ...      ...         ...               ...                               ...
# 4995  245706   tt2273657                en                        True Story
# 4996   41515   tt1302067                en                         Yogi Bear
# 4997   19593   tt0099387                en  The Death of the Incredible Hulk
# 4998   19898   tt1188729                en                          Pandorum
# 4999   24001   tt0907676                en                 The Hills Run Red
#
#                                                overview  popularity  \
# 0     Peter Parker is unmasked and no longer able to...   10552.154
# 1     In his second year of fighting crime, Batman u...    3956.450
# 2     Stranded at a rest stop in the mountains durin...    3434.009
# 3     The tale of an extraordinary family, the Madri...    3275.706
# 4     After going to extremes to cover up an acciden...    2371.051
# ...                                                 ...         ...
# 4995  A drama centered around the relationship betwe...      26.610
# 4996  A documentary filmmaker travels to Jellystone ...      29.024
# 4997  During the critical experiment that would rid ...      24.156
# 4998  Two crew members wake up on an abandoned space...      24.698
# 4999  A group of young horror fans go searching for ...      25.050
#
#                                    production_companies  ...     revenue  \
# 0     [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...  ...  1876685954
# 1     [{'id': 101405, 'logo_path': None, 'name': '6t...  ...   463220826
# 2     [{'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEn...  ...           0
# 3     [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...  ...   240000000
# 4     [{'id': 152208, 'logo_path': None, 'name': 'Br...  ...           0
# ...                                                 ...  ...         ...
# 4995  [{'id': 81, 'logo_path': '/8wOfUhA7vwU2gbPjQy7...  ...     5261595
# 4996  [{'id': 5219, 'logo_path': None, 'name': 'Suns...  ...   203509374
# 4997  [{'id': 4608, 'logo_path': None, 'name': 'New ...  ...           0
# 4998  [{'id': 248, 'logo_path': None, 'name': 'Impac...  ...    20648328
# 4999  [{'id': 1786, 'logo_path': '/joLFuCWg9e2lweYnF...  ...           0
#
#      runtime                                   spoken_languages  \
# 0      148.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      176.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2       96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      102.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4       95.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# ...      ...                                                ...
# 4995    99.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4996    80.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4997    95.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4998   108.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4999    81.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                 tagline  \
# 0                             The Multiverse unleashed.
# 1                                     Unmask the truth.
# 2                  Who will survive the dead of winter?
# 3     There's a little magic in all of us ...almost ...
# 4                                                   NaN
# ...                                                 ...
# 4995                  Some mysteries are beyond belief.
# 4996                      Please do not feed the bears.
# 4997  For 12 years, he's been running. Tonight, it's...
# 4998  Don't fear the end of the world. Fear what hap...
# 4999                 Trespassers will be slaughtered...
#
#                                  title vote_average vote_count  \
# 0              Spider-Man: No Way Home          8.3       9509
# 1                           The Batman          8.0       1738
# 2                              No Exit          6.5        208
# 3                              Encanto          7.7       5282
# 4                             Restless          5.9        152
# ...                                ...          ...        ...
# 4995                        True Story          6.3       1630
# 4996                         Yogi Bear          5.6        704
# 4997  The Death of the Incredible Hulk          5.0         57
# 4998                          Pandorum          6.5       1847
# 4999                 The Hills Run Red          5.7        210
#
#                                                 credits  \
# 0     {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 1     {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 2     {'cast': [{'adult': False, 'gender': 1, 'id': ...
# 3     {'cast': [{'adult': False, 'gender': 1, 'id': ...
# 4     {'cast': [{'adult': False, 'gender': 2, 'id': ...
# ...                                                 ...
# 4995  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 4996  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 4997  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 4998  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 4999  {'cast': [{'adult': False, 'gender': 1, 'id': ...
#
#                                                keywords released
# 0     {'keywords': [{'id': 242, 'name': 'new york ci...     True
# 1     {'keywords': [{'id': 849, 'name': 'dc comics'}...     True
# 2     {'keywords': [{'id': 818, 'name': 'based on no...     True
# 3     {'keywords': [{'id': 2343, 'name': 'magic'}, {...     True
# 4        {'keywords': [{'id': 9714, 'name': 'remake'}]}     True
# ...                                                 ...      ...
# 4995  {'keywords': [{'id': 378, 'name': 'prison'}, {...     True
# 4996  {'keywords': [{'id': 2406, 'name': 'picnic'}, ...     True
# 4997  {'keywords': [{'id': 9181, 'name': 'alter ego'...     True
# 4998  {'keywords': [{'id': 1612, 'name': 'spacecraft...     True
# 4999  {'keywords': [{'id': 6259, 'name': 'psychopath...     True
#
# [5000 rows x 22 columns]

# %% [markdown]
# The columns `genres`, `production_companies`, `production_countries`, `spoken_languages`,
# `credits`, and `keywords` are lists of quasi-JSON style strings. However, single
# quotes have been used, so instead we store them in the dataframe as lists of
# dictionaries.

# %%
# parse columns with nested JSON objects as actual JSON objects instead of str
json_cols = [
    "genres", "production_companies", "production_countries", "spoken_languages", 
    "credits", "keywords"
]

for col in json_cols:
    raw_data[col] = raw_data[col].apply(ast.literal_eval)

raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 5000 non-null   bool
#  1   budget                5000 non-null   int64
#  2   genres                5000 non-null   object
#  3   id                    5000 non-null   int64
#  4   imdb_id               4938 non-null   object
#  5   original_language     5000 non-null   object
#  6   original_title        5000 non-null   object
#  7   overview              4963 non-null   object
#  8   popularity            5000 non-null   float64
#  9   production_companies  5000 non-null   object
#  10  production_countries  5000 non-null   object
#  11  release_date          4980 non-null   datetime64[ns]
#  12  revenue               5000 non-null   int64
#  13  runtime               4999 non-null   float64
#  14  spoken_languages      5000 non-null   object
#  15  status                5000 non-null   object
#  16  tagline               3750 non-null   object
#  17  title                 5000 non-null   object
#  18  vote_average          5000 non-null   float64
#  19  vote_count            5000 non-null   int64
#  20  credits               5000 non-null   object
#  21  keywords              5000 non-null   object
#  22  released              5000 non-null   bool
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(4), object(13)
# memory usage: 830.2+ KB

# %% [markdown]
# Due to the use of `ast.literal_eval`, we have ended up with the following columns:
#
# - `genres`, `production_companies`, `production_countries`, `spoken_languages` are lists
# - `credits` and `keywords` are dictionaries.
#
# Morevover, credits has keys `cast` and `crew`, while keywords simply has one
# key `keywords`. The corresponding values are in the same list of dictionaries structure
# as above. Hence, the best way to clean this data is to create two new columns
# for `cast` and `crew`, and simply reassign the `keywords` column to the actual
# value inside `keywords`.

# %%
list_cols = ["genres", "production_companies", "production_countries", "spoken_languages",
                "cast", "crew", "keywords"]

cast = []
crew = []
for movie in raw_data["credits"]:
    cast.append(movie["cast"])
    crew.append(movie["crew"])
raw_data["cast"] = pd.Series(cast)
raw_data["crew"] = pd.Series(crew)

new_keywords = []
for movie in raw_data["keywords"]:
    new_keywords.append(movie["keywords"])
raw_data["keywords"] = pd.Series(new_keywords)

def helper(col):
    new_col = []
    for val in col:
        new_val = []
        for x in val:
            new_val.append(dict(x))
        
        new_col.append(new_val)
    
    return pd.Series(new_col)

for col in list_cols:
    raw_data[col] = helper(raw_data[col])
    print(col + " done")
# Out:
# genres done
# production_companies done
# production_countries done
# spoken_languages done
# cast done
# crew done
# keywords done

# %% [markdown]
# We can now drop the `credits` column.

# %%
raw_data.drop("credits", axis=1, inplace=True)
raw_data.head()
# Out:
#    adult     budget                                             genres  \
# 0  False  200000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1  False  185000000  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 2  False          0  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 3  False   50000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  False          0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#        id     imdb_id original_language           original_title  \
# 0  634649  tt10872600                en  Spider-Man: No Way Home
# 1  414906   tt1877830                en               The Batman
# 2  833425   tt7550014                en                  No Exit
# 3  568124   tt2953050                en                  Encanto
# 4  928381  tt14465894                fr               Sans répit
#
#                                             overview  popularity  \
# 0  Peter Parker is unmasked and no longer able to...   10552.154
# 1  In his second year of fighting crime, Batman u...    3956.450
# 2  Stranded at a rest stop in the mountains durin...    3434.009
# 3  The tale of an extraordinary family, the Madri...    3275.706
# 4  After going to extremes to cover up an acciden...    2371.051
#
#                                 production_companies  ...  \
# 0  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...  ...
# 1  [{'id': 101405, 'logo_path': None, 'name': '6t...  ...
# 2  [{'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEn...  ...
# 3  [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...  ...
# 4  [{'id': 152208, 'logo_path': None, 'name': 'Br...  ...
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
#
#                                              tagline                    title  \
# 0                          The Multiverse unleashed.  Spider-Man: No Way Home
# 1                                  Unmask the truth.               The Batman
# 2               Who will survive the dead of winter?                  No Exit
# 3  There's a little magic in all of us ...almost ...                  Encanto
# 4                                                NaN                 Restless
#
#   vote_average vote_count                                           keywords  \
# 0          8.3       9509  [{'id': 242, 'name': 'new york city'}, {'id': ...
# 1          8.0       1738  [{'id': 849, 'name': 'dc comics'}, {'id': 853,...
# 2          6.5        208  [{'id': 818, 'name': 'based on novel or book'}...
# 3          7.7       5282  [{'id': 2343, 'name': 'magic'}, {'id': 4344, '...
# 4          5.9        152                   [{'id': 9714, 'name': 'remake'}]
#
#   released                                               cast  \
# 0     True  [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 1     True  [{'adult': False, 'gender': 2, 'id': 11288, 'k...
# 2     True  [{'adult': False, 'gender': 1, 'id': 2378813, ...
# 3     True  [{'adult': False, 'gender': 1, 'id': 968367, '...
# 4     True  [{'adult': False, 'gender': 2, 'id': 1077537, ...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 1, 'id': 2519, 'kn...
# 1  [{'adult': False, 'gender': 2, 'id': 2122, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 2199, 'kn...
# 3  [{'adult': False, 'gender': 0, 'id': 8159, 'kn...
# 4  [{'adult': False, 'gender': 0, 'id': 64130, 'k...
#
# [5 rows x 24 columns]

# %% [markdown]
# The column `genres` has a structure such that each film has a list of key-value pairs, e.g. `['id':28, 'name': 'Action',...]`. We don't need this key-value structure, so we just keep a list of the `name` of genres of a film. Same applies to columns `production_companies`, `production_countries`, `spoken_languages`, and `keywords`.
#
# We don't apply this to `cast` and `crew` because every production team member
# has additional information such as their gender, role, etc..

# %%
# need a copy to avoid SettingWithoutCopyWarning
raw_data_copy = raw_data.copy()
for i in range(0, raw_data.shape[0], 1):
    # extract the relevant values of these columns
    genres_names = [x["name"] for x in raw_data_copy.iloc[i]["genres"]]
    production_companies_names = [x["name"] for x in raw_data_copy.iloc[i]["production_companies"]]
    production_countries_names = [x["iso_3166_1"] for x in raw_data_copy.iloc[i]["production_countries"]]
    spoken_languages_names = [x["iso_639_1"] for x in raw_data_copy.iloc[i]["spoken_languages"]]
    keywords_names = [x["name"] for x in raw_data_copy.iloc[i]["keywords"]]

    # reassign entry values
    raw_data.at[i, "genres"] = genres_names
    raw_data.at[i, "production_companies"] = production_companies_names
    raw_data.at[i, "production_countries"] = production_countries_names
    raw_data.at[i, "spoken_languages"] = spoken_languages_names
    raw_data.at[i, "keywords"] = keywords_names

# %%
raw_data[["genres", "production_companies", "production_countries", "spoken_languages","keywords"]].head()
# Out:
#                                  genres  \
# 0  [Action, Adventure, Science Fiction]
# 1            [Crime, Mystery, Thriller]
# 2                    [Horror, Thriller]
# 3  [Animation, Comedy, Family, Fantasy]
# 4             [Action, Thriller, Crime]
#
#                                 production_companies production_countries  \
# 0  [Marvel Studios, Pascal Pictures, Columbia Pic...                 [US]
# 1  [6th & Idaho, Dylan Clark Productions, DC Film...                 [US]
# 2                  [20th Century Studios, Flitcraft]                 [US]
# 3  [Walt Disney Animation Studios, Walt Disney Pi...                 [US]
# 4          [Bright Lights Films, uMedia, Mahi Films]             [BE, FR]
#
#   spoken_languages                                           keywords
# 0         [en, tl]  [new york city, hero, villain, comic book, seq...
# 1             [en]  [dc comics, crime fighter, secret identity, vi...
# 2             [en]  [based on novel or book, winter, isolation, bl...
# 3         [en, es]  [magic, musical, forest, family relationships,...
# 4             [fr]                                           [remake]

# %% [markdown]
# We finally have lists of valid JSON strings inside the columns. We are now ready to flatten the data and perform one-hot encoding. Whether or not a column should be flattened or one-hot encoded depends on the structure of the model being used. Hence, we define functions to perform either for future use.

# %%
# creates a flat dataframe based on any column
def flatten(df: pd.DataFrame, cols: list):
    """
    INPUTS:
        df:     (pd.DataFrame) a dataframe
        cols:   (list) list of column names in df
    OUTPUTS:
                (pd.DataFrame) a dataframe flattened according to cols
    """

    for col in cols:
        df = df.explode(col)
    
    return df

# creates a new one-hot encoded dataframe based on any column
def one_hot(df: pd.DataFrame, cols: list):
    """
    INPUTS:
        df:     (pd.DataFrame) a dataframe
        cols:   (list) list of column names in df
    OUTPUTS:
                (pd.DataFrame) a dataframe one-hot encoded according to cols
    """
    # flatten data on col
    flat_df = flatten(df, cols)
    
    # one-hot encode flat_df using pd.get_dummies()
    return pd.get_dummies(flat_df, columns=cols).groupby(flat_df.index).max()

# %% [markdown]
# Now we work with `cast` and `crew` columns. For any movie, `cast` (or `crew`) contains a list of people stored as dictionaries. Hence, we need a different approach to flatten the data for people columns.

# %%
# # creates a flat dataframe based on any column
def flatten_people(df: pd.DataFrame, col: str):
    """
    INPUTS:
        df:     (pd.DataFrame) a dataframe
        col:    (str) cast or crew
    OUTPUTS:
                (pd.DataFrame) a dataframe flattened according to col
    """

    ls_of_temps = []
    for i in range(0, df.shape[0], 1):
        temp_df = pd.json_normalize(df[col][i])
        temp_df["movie_id"] = df["id"][i]
        temp_df["movie_title"] = df["title"][i]

        temp_df.columns = [col + "_tmdb_" + x if x == "id" else x for x in temp_df.columns]
        temp_df.columns = [col + "_" + x if x == "name" else x for x in temp_df.columns]
        
        ls_of_temps.append(temp_df)
    
    return pd.concat(ls_of_temps)

# %% [markdown]
# Once flattened, `one_hot()` can be used.

# %% [markdown]
# We store the cleaned data for use in the next notebook.

# %%
# %store raw_data
# Out:
# Stored 'raw_data' (DataFrame)
